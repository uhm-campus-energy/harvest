# %% [markdown]
# <div class="alert alert-warning">Ensure data already extracted from MeterDataTest folder and preprocessed using harvest_kwh.ipynb

# %% [markdown]
# ## 2b. Processing harvest kw data
# Using processing_kw.py (pkw) functions
# * Loads, cleans, standardizes data
# * Calculate average kw per 15 min intervals
#     * Adjust to meter models: PQM2 (reports in kw), EPM7000 (reports in watts)
#     * <div style="color:red">Need meter model guide (in notebooks folder)
# * Option to process data in certain time frame

# %% [markdown]
# <div style="color:blue">Enter input:

# %%
# data input csv
data_path = 'save_data_col.csv' # preprocessed harvest data from meter_data.ipynb

# guide of the meters with their meter model types
info_path = 'all_headers.csv' # given by Eileen

# True if want to process data in a certain time frame, False to process all data
time_frame = False
#start_dt = '2023-09-07 00:00:00' # comment out if processing all data
#end_dt = '2023-09-09 23:59:59' # comment out if processing all data

##########################################################################

# processed harvest kw data csv
#harvest
#var
#dt

# %% [markdown]
# Imports:

# %%
import os, sys
sys.path.append(os.path.abspath('..'))
import harvest_kw as pkw # import self defined module

# %% [markdown]
# Loading/Processing:

# %%
# load meter data and info from csvs into dataframes, cleaned and reformatted
df, info_df = pkw.load_data(data_path, info_path)

# process data for only dates ie: sept 7-9
if time_frame:
    df = pkw.filter_time_frame(df, start_dt, end_dt)

# processed kw data in dataframe
result_df = pkw.process_kw_data(df, info_df)

# create csv of processed data
result_df.to_csv('processed_kw.csv', index=False)
